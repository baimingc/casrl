# %%
import time, datetime
import copy
import os
import sys
import warnings
#warnings.filterwarnings("ignore", category=UserWarning)
#warnings.filterwarnings("ignore", category=RuntimeWarning)

import numpy as np
from loguru import logger
import yaml
from utils import dumb_reward_plot
import gym

sys.path.append('./envs/cartpole-envs')
sys.path.append('./')
import cartpole_envs
#import highway_env

from utils import plot_reward, plot_index
from mpc.mpc_cp import MPC
from baselines.NP_epi import NP

def prepare_dynamics(gym_config):
    dynamics_name = gym_config['dynamics_name']
    seed = gym_config['seed']
    dynamics_set = []
    for i in range(len(dynamics_name)):
        env = gym.make(dynamics_name[i])
        # env.seed(seed)
        dynamics_set.append(gym.make(dynamics_name[i]))
    
    # use pre-defined env sequence
    task = [dynamics_set[i] for i in gym_config['task_dynamics_list']]
    return task

def load_config(config_path="config.yml"):
    if os.path.isfile(config_path):
        f = open(config_path)
        return yaml.load(f, Loader=yaml.FullLoader)
    else:
        raise Exception("Configuration file is not found in the path: "+config_path)

# %%
# config = load_config('config/config_cpstable_np.yml')
# config = load_config('config/config_cp_np.yml')
config = load_config('config/config_cp_np_delay.yml')
mpc_config = config['mpc_config']
gym_config = config['gym_config']
render = gym_config['render']
np_config = config['NP_config']

# initialize the mixture model
# NOTICE: Model
#  ###########
model = NP(NP_config=np_config)
logger.info('Using model: {}', model.name)

# initial MPC controller
mpc_controller = MPC(mpc_config=mpc_config)

# prepare task
# the task is solved, if each dynamic is solved
task = prepare_dynamics(gym_config)
print(gym_config)

"""start DPGP-MBRL"""
data_buffer = []
label_list = []
subtask_list = []
subtask_reward = []
subtask_succ_count = [0]
comp_trainable = [1]
task_reward = []
trainable = True
task_solved = False
subtask_solved = [False, False, False, False]
total_count = 0
task_epi = 0
log_name = None

max_delay_step = gym_config["max_delay_step"]
total_tasks = 1  #4
# Out:
# 2020-05-24 20:47:11.328 | INFO     | __main__:<module>:13 - Using model: NP
# {'render': False, 'task_dynamics_list': [0, 1, 2, 3], 'subtask_episode': 3, 'subtask_episode_length': 200, 'task_episode': 100, 'seed': 1000, 'dynamics_name': ['CartPoleSwingUpEnvCm05Pm04Pl05-v0', 'CartPoleSwingUpEnvCm05Pm04Pl07-v0', 'CartPoleSwingUpEnvCm05Pm08Pl05-v0', 'CartPoleSwingUpEnvCm05Pm08Pl07-v0'], 'max_delay_step': 4}

# %%
"""NP pretrain"""
pretrain_episodes = 100
for task_idx in range(total_tasks):
    env = task[task_idx]
    # data collection
    for epi in range(pretrain_episodes):
        act_buf = np.zeros(max_delay_step+1)
        delay_step = np.random.randint(0,max_delay_step-1)
#         delay_step = 4
        obs = env.reset()
        done = False
        mpc_controller.reset()
        while not done:
            action = env.action_space.sample()
            act_buf = np.concatenate((act_buf, action))[1:]
            obs_next, reward, done, state_next = env.step([act_buf[-1-delay_step]])
#             print(np.concatenate((obs, act_buf[:-1])),action, np.concatenate((obs_next - obs, act_buf[1:])) )
            model.data_process([0, np.concatenate((obs, act_buf[:-1])), action, np.concatenate((obs_next - obs, act_buf[1:]))])
            obs = copy.deepcopy(obs_next)
        model.fit()
        model.reset()
# NOTICE: Model
#  ###########
# model.validation_flag = True
# model.fit()

# %%
"""testing the model with MPC while training """
test_episode = 1
test_epoch = 1000
log = []
for ep in range(test_epoch):
    print('epoch: ', ep)
    for task_idx in range(total_tasks):
        env = task[task_idx]
        print('task: ', task_idx)
        for epi in range(test_episode):
            #print('episode: ', epi)
            acc_reward = 0
            obs = env.reset()
            act_buf = np.zeros(max_delay_step+1)
            delay_step = np.random.randint(0,max_delay_step)
#             delay_step = 4
            O, A, R, acc_reward, done = [], [], [], 0, False
            mpc_controller.reset()
            i = 0
            while not done:
                i+= 1
                # env.render()
                env_copy = prepare_dynamics(gym_config)[task_idx]
                env_copy.reset()
                # NOTICE: Model
                #  ###########
                act_buf = act_buf[1:]
                action = np.array([0.0])
                if i > 1:
                    action = np.array([mpc_controller.act(task=env_copy, model=model, state=np.concatenate((obs, act_buf)))])
                act_buf = np.concatenate((act_buf, action))
                obs_next, reward, done, state_next = env.step([act_buf[-1-delay_step]])
                model.data_process([0, np.concatenate((obs, act_buf[:-1])), action, np.concatenate((obs_next - obs, act_buf[1:]))])
#                 print(np.concatenate((obs, act_buf[:-1])), action, np.concatenate((obs_next - obs, act_buf[1:])))
                A.append(action)
                O.append(state_next)
                R.append(reward)
                obs = copy.deepcopy(obs_next)
                acc_reward += reward
                # logger.info('reward: {}', reward)
                #time.sleep(0.1)
            print('task: ', task_idx,'delay: ', delay_step,'step: ', i, 'acc_reward: ', acc_reward)
            env.close()

            if done:
                samples = {
                    "obs": np.array(O),
                    "actions": np.array(A),
                    "rewards": np.array(R),
                    "reward_sum": acc_reward,
                }
                print('******************')
                print('acc_reward', acc_reward)
                print('******************')
                log.append(samples)
                if log_name is None:
                    log_name = datetime.datetime.now()
                path = './misc/log/' + log_name.strftime("%d-%H-%M") + '.npy'
                np.save(path, log, allow_pickle=True)
                dumb_reward_plot(path)
            model.fit()
            model.reset()

        # use the collected date to train model
#         print('fitting the model...')
        #model.n_epochs = 20

        # NOTICE: Model
        #  ###########
# Out:
# epoch:  0
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  31.724881510974296
# ******************
# acc_reward 31.724881510974296
# ******************
# epoch:  1
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  38.31195246944633
# ******************
# acc_reward 38.31195246944633
# ******************
# epoch:  2
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  37.2869399043944
# ******************
# acc_reward 37.2869399043944
# ******************
# epoch:  3
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  51.08440320972407
# ******************
# acc_reward 51.08440320972407
# ******************
# epoch:  4
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  68.34341225289945
# ******************
# acc_reward 68.34341225289945
# ******************
# epoch:  5
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  75.73660322962249
# ******************
# acc_reward 75.73660322962249
# ******************
# epoch:  6
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  68.02388064003732
# ******************
# acc_reward 68.02388064003732
# ******************
# epoch:  7
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  93.28339703842958
# ******************
# acc_reward 93.28339703842958
# ******************
# epoch:  8
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  72.70744196596756
# ******************
# acc_reward 72.70744196596756
# ******************
# epoch:  9
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  58.17830520407807
# ******************
# acc_reward 58.17830520407807
# ******************
# epoch:  10
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  79.40076235853408
# ******************
# acc_reward 79.40076235853408
# ******************
# epoch:  11
# task:  0
# task:  0 delay:  0 step:  73 acc_reward:  24.640335176527365
# ******************
# acc_reward 24.640335176527365
# ******************
# epoch:  12
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  61.22228611598998
# ******************
# acc_reward 61.22228611598998
# ******************
# epoch:  13
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  89.85405988137468
# ******************
# acc_reward 89.85405988137468
# ******************
# epoch:  14
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  49.807011527087035
# ******************
# acc_reward 49.807011527087035
# ******************
# epoch:  15
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  71.48565977906343
# ******************
# acc_reward 71.48565977906343
# ******************
# epoch:  16
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  58.32604259928811
# ******************
# acc_reward 58.32604259928811
# ******************
# epoch:  17
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  53.64755611684734
# ******************
# acc_reward 53.64755611684734
# ******************
# epoch:  18
# task:  0
# task:  0 delay:  1 step:  36 acc_reward:  5.5955913521711755
# ******************
# acc_reward 5.5955913521711755
# ******************
# epoch:  19
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  98.62356269741085
# ******************
# acc_reward 98.62356269741085
# ******************
# epoch:  20
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  27.304381612560636
# ******************
# acc_reward 27.304381612560636
# ******************
# epoch:  21
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  65.16259689504328
# ******************
# acc_reward 65.16259689504328
# ******************
# epoch:  22
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  60.94246157411912
# ******************
# acc_reward 60.94246157411912
# ******************
# epoch:  23
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  55.488338441212385
# ******************
# acc_reward 55.488338441212385
# ******************
# epoch:  24
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  46.852949561877864
# ******************
# acc_reward 46.852949561877864
# ******************
# epoch:  25
# task:  0
# task:  0 delay:  2 step:  22 acc_reward:  2.8744530812109375
# ******************
# acc_reward 2.8744530812109375
# ******************
# epoch:  26
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  46.20615282529385
# ******************
# acc_reward 46.20615282529385
# ******************
# epoch:  27
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  61.1492831353846
# ******************
# acc_reward 61.1492831353846
# ******************
# epoch:  28
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  106.02590224679506
# ******************
# acc_reward 106.02590224679506
# ******************
# epoch:  29
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  62.44268792506763
# ******************
# acc_reward 62.44268792506763
# ******************
# epoch:  30
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  58.850875926834654
# ******************
# acc_reward 58.850875926834654
# ******************
# epoch:  31
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  63.71741393302892
# ******************
# acc_reward 63.71741393302892
# ******************
# epoch:  32
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  65.23776463075674
# ******************
# acc_reward 65.23776463075674
# ******************
# epoch:  33
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  64.54932475078265
# ******************
# acc_reward 64.54932475078265
# ******************
# epoch:  34
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  87.84265607064665
# ******************
# acc_reward 87.84265607064665
# ******************
# epoch:  35
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  83.00698043136381
# ******************
# acc_reward 83.00698043136381
# ******************
# epoch:  36
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  83.46940891069593
# ******************
# acc_reward 83.46940891069593
# ******************
# epoch:  37
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  30.58942920970125
# ******************
# acc_reward 30.58942920970125
# ******************
# epoch:  38
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  48.70518468902955
# ******************
# acc_reward 48.70518468902955
# ******************
# epoch:  39
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  66.83104287965519
# ******************
# acc_reward 66.83104287965519
# ******************
# epoch:  40
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  61.978215937335065
# ******************
# acc_reward 61.978215937335065
# ******************
# epoch:  41
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  52.42778338755696
# ******************
# acc_reward 52.42778338755696
# ******************
# epoch:  42
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  52.22737723758734
# ******************
# acc_reward 52.22737723758734
# ******************
# epoch:  43
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  66.86883925749349
# ******************
# acc_reward 66.86883925749349
# ******************
# epoch:  44
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  75.47532736040776
# ******************
# acc_reward 75.47532736040776
# ******************
# epoch:  45
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  79.52999425750107
# ******************
# acc_reward 79.52999425750107
# ******************
# epoch:  46
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  74.4282777548741
# ******************
# acc_reward 74.4282777548741
# ******************
# epoch:  47
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  93.24837515809578
# ******************
# acc_reward 93.24837515809578
# ******************
# epoch:  48
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  70.26017620338995
# ******************
# acc_reward 70.26017620338995
# ******************
# epoch:  49
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  81.22482541160046
# ******************
# acc_reward 81.22482541160046
# ******************
# epoch:  50
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  55.19151507195362
# ******************
# acc_reward 55.19151507195362
# ******************
# epoch:  51
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  91.43318820669231
# ******************
# acc_reward 91.43318820669231
# ******************
# epoch:  52
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  101.31921675863802
# ******************
# acc_reward 101.31921675863802
# ******************
# epoch:  53
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  93.2211838092247
# ******************
# acc_reward 93.2211838092247
# ******************
# epoch:  54
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  90.24791153549857
# ******************
# acc_reward 90.24791153549857
# ******************
# epoch:  55
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  30.633385048140486
# ******************
# acc_reward 30.633385048140486
# ******************
# epoch:  56
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  34.06967769744963
# ******************
# acc_reward 34.06967769744963
# ******************
# epoch:  57
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  70.32575431529013
# ******************
# acc_reward 70.32575431529013
# ******************
# epoch:  58
# task:  0
# task:  0 delay:  2 step:  175 acc_reward:  66.28167724991421
# ******************
# acc_reward 66.28167724991421
# ******************
# epoch:  59
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  94.38064848389209
# ******************
# acc_reward 94.38064848389209
# ******************
# epoch:  60
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  104.84991983779176
# ******************
# acc_reward 104.84991983779176
# ******************
# epoch:  61
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  72.67470648919154
# ******************
# acc_reward 72.67470648919154
# ******************
# epoch:  62
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  65.46690155965322
# ******************
# acc_reward 65.46690155965322
# ******************
# epoch:  63
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  61.48062198085438
# ******************
# acc_reward 61.48062198085438
# ******************
# epoch:  64
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  44.40929887326939
# ******************
# acc_reward 44.40929887326939
# ******************
# epoch:  65
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  31.014073471233125
# ******************
# acc_reward 31.014073471233125
# ******************
# epoch:  66
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  75.42366795733854
# ******************
# acc_reward 75.42366795733854
# ******************
# epoch:  67
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  59.70752903441928
# ******************
# acc_reward 59.70752903441928
# ******************
# epoch:  68
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  67.55886267176484
# ******************
# acc_reward 67.55886267176484
# ******************
# epoch:  69
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  59.10277272813001
# ******************
# acc_reward 59.10277272813001
# ******************
# epoch:  70
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  76.35772551808247
# ******************
# acc_reward 76.35772551808247
# ******************
# epoch:  71
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  85.042486331699
# ******************
# acc_reward 85.042486331699
# ******************
# epoch:  72
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  75.68529648618669
# ******************
# acc_reward 75.68529648618669
# ******************
# epoch:  73
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  74.60662377561333
# ******************
# acc_reward 74.60662377561333
# ******************
# epoch:  74
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  56.00491914008264
# ******************
# acc_reward 56.00491914008264
# ******************
# epoch:  75
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  75.6600914569826
# ******************
# acc_reward 75.6600914569826
# ******************
# epoch:  76
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  55.530916870780466
# ******************
# acc_reward 55.530916870780466
# ******************
# epoch:  77
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  60.628742653820396
# ******************
# acc_reward 60.628742653820396
# ******************
# epoch:  78
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  57.958491048014054
# ******************
# acc_reward 57.958491048014054
# ******************
# epoch:  79
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  53.94401261221355
# ******************
# acc_reward 53.94401261221355
# ******************
# epoch:  80
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  57.71592382567886
# ******************
# acc_reward 57.71592382567886
# ******************
# epoch:  81
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  83.75479785369386
# ******************
# acc_reward 83.75479785369386
# ******************
# epoch:  82
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  71.93488874126037
# ******************
# acc_reward 71.93488874126037
# ******************
# epoch:  83
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  24.829267151191036
# ******************
# acc_reward 24.829267151191036
# ******************
# epoch:  84
# task:  0
# task:  0 delay:  2 step:  28 acc_reward:  9.548156615114607
# ******************
# acc_reward 9.548156615114607
# ******************
# epoch:  85
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  68.69973536451464
# ******************
# acc_reward 68.69973536451464
# ******************
# epoch:  86
# task:  0
# task:  0 delay:  0 step:  152 acc_reward:  61.76861755013842
# ******************
# acc_reward 61.76861755013842
# ******************
# epoch:  87
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  60.91654999590069
# ******************
# acc_reward 60.91654999590069
# ******************
# epoch:  88
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  72.36917857211958
# ******************
# acc_reward 72.36917857211958
# ******************
# epoch:  89
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  105.23738043970893
# ******************
# acc_reward 105.23738043970893
# ******************
# epoch:  90
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  60.22053617560825
# ******************
# acc_reward 60.22053617560825
# ******************
# epoch:  91
# task:  0
# task:  0 delay:  3 step:  43 acc_reward:  2.9043349034266344
# ******************
# acc_reward 2.9043349034266344
# ******************
# epoch:  92
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  68.53800999604356
# ******************
# acc_reward 68.53800999604356
# ******************
# epoch:  93
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  123.54606178526755
# ******************
# acc_reward 123.54606178526755
# ******************
# epoch:  94
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  89.57426773811753
# ******************
# acc_reward 89.57426773811753
# ******************
# epoch:  95
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  71.29543174476596
# ******************
# acc_reward 71.29543174476596
# ******************
# epoch:  96
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  65.16305849351659
# ******************
# acc_reward 65.16305849351659
# ******************
# epoch:  97
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  72.23154330268125
# ******************
# acc_reward 72.23154330268125
# ******************
# epoch:  98
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  68.60247561742784
# ******************
# acc_reward 68.60247561742784
# ******************
# epoch:  99
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  100.30830581707659
# ******************
# acc_reward 100.30830581707659
# ******************
# epoch:  100
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  83.77118218988723
# ******************
# acc_reward 83.77118218988723
# ******************
# epoch:  101
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  105.29989324516002
# ******************
# acc_reward 105.29989324516002
# ******************
# epoch:  102
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  41.78938001184133
# ******************
# acc_reward 41.78938001184133
# ******************
# epoch:  103
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  47.40092629159951
# ******************
# acc_reward 47.40092629159951
# ******************
# epoch:  104
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  38.62930225768492
# ******************
# acc_reward 38.62930225768492
# ******************
# epoch:  105
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  103.75436738198846
# ******************
# acc_reward 103.75436738198846
# ******************
# epoch:  106
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  161.4177747821668
# ******************
# acc_reward 161.4177747821668
# ******************
# epoch:  107
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  113.1979672730927
# ******************
# acc_reward 113.1979672730927
# ******************
# epoch:  108
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  162.61327546390484
# ******************
# acc_reward 162.61327546390484
# ******************
# epoch:  109
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  15.835456483842204
# ******************
# acc_reward 15.835456483842204
# ******************
# epoch:  110
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  39.74181613618725
# ******************
# acc_reward 39.74181613618725
# ******************
# epoch:  111
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  45.24772142447374
# ******************
# acc_reward 45.24772142447374
# ******************
# epoch:  112
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  60.00857851437036
# ******************
# acc_reward 60.00857851437036
# ******************
# epoch:  113
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  56.75704093155251
# ******************
# acc_reward 56.75704093155251
# ******************
# epoch:  114
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  60.33712874060047
# ******************
# acc_reward 60.33712874060047
# ******************
# epoch:  115
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  63.230817584157414
# ******************
# acc_reward 63.230817584157414
# ******************
# epoch:  116
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  66.91950164518893
# ******************
# acc_reward 66.91950164518893
# ******************
# epoch:  117
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  79.95204962923161
# ******************
# acc_reward 79.95204962923161
# ******************
# epoch:  118
# task:  0
# task:  0 delay:  1 step:  159 acc_reward:  70.40578012434013
# ******************
# acc_reward 70.40578012434013
# ******************
# epoch:  119
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  66.25412361870535
# ******************
# acc_reward 66.25412361870535
# ******************
# epoch:  120
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  124.6433847514933
# ******************
# acc_reward 124.6433847514933
# ******************
# epoch:  121
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  107.06428576662681
# ******************
# acc_reward 107.06428576662681
# ******************
# epoch:  122
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  55.88873679941729
# ******************
# acc_reward 55.88873679941729
# ******************
# epoch:  123
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  84.63244384616932
# ******************
# acc_reward 84.63244384616932
# ******************
# epoch:  124
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  90.10780309152996
# ******************
# acc_reward 90.10780309152996
# ******************
# epoch:  125
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  69.27455461113273
# ******************
# acc_reward 69.27455461113273
# ******************
# epoch:  126
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  67.94610867905506
# ******************
# acc_reward 67.94610867905506
# ******************
# epoch:  127
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  53.49767207789867
# ******************
# acc_reward 53.49767207789867
# ******************
# epoch:  128
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  67.0403094039107
# ******************
# acc_reward 67.0403094039107
# ******************
# epoch:  129
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  50.7731233032627
# ******************
# acc_reward 50.7731233032627
# ******************
# epoch:  130
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  154.036648980476
# ******************
# acc_reward 154.036648980476
# ******************
# epoch:  131
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  149.8503040524347
# ******************
# acc_reward 149.8503040524347
# ******************
# epoch:  132
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  101.05849763451758
# ******************
# acc_reward 101.05849763451758
# ******************
# epoch:  133
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  94.91819547306494
# ******************
# acc_reward 94.91819547306494
# ******************
# epoch:  134
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  108.60574274897128
# ******************
# acc_reward 108.60574274897128
# ******************
# epoch:  135
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  141.33166192076865
# ******************
# acc_reward 141.33166192076865
# ******************
# epoch:  136
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  74.44779064851865
# ******************
# acc_reward 74.44779064851865
# ******************
# epoch:  137
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  70.69981899612823
# ******************
# acc_reward 70.69981899612823
# ******************
# epoch:  138
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  90.96137650885444
# ******************
# acc_reward 90.96137650885444
# ******************
# epoch:  139
# task:  0
# task:  0 delay:  3 step:  22 acc_reward:  1.4707144948499382
# ******************
# acc_reward 1.4707144948499382
# ******************
# epoch:  140
# task:  0
# task:  0 delay:  1 step:  54 acc_reward:  9.334266855807446
# ******************
# acc_reward 9.334266855807446
# ******************
# epoch:  141
# task:  0
# task:  0 delay:  0 step:  24 acc_reward:  1.619001460853293
# ******************
# acc_reward 1.619001460853293
# ******************
# epoch:  142
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  120.75618141961674
# ******************
# acc_reward 120.75618141961674
# ******************
# epoch:  143
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  66.91505452213494
# ******************
# acc_reward 66.91505452213494
# ******************
# epoch:  144
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  50.35550827352681
# ******************
# acc_reward 50.35550827352681
# ******************
# epoch:  145
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  61.52499949026434
# ******************
# acc_reward 61.52499949026434
# ******************
# epoch:  146
# task:  0
# task:  0 delay:  3 step:  34 acc_reward:  3.1966954891139494
# ******************
# acc_reward 3.1966954891139494
# ******************
# epoch:  147
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  64.29952017646595
# ******************
# acc_reward 64.29952017646595
# ******************
# epoch:  148
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  54.327258953487046
# ******************
# acc_reward 54.327258953487046
# ******************
# epoch:  149
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  65.85999715640529
# ******************
# acc_reward 65.85999715640529
# ******************
# epoch:  150
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  66.97846412335196
# ******************
# acc_reward 66.97846412335196
# ******************
# epoch:  151
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  72.5576999172655
# ******************
# acc_reward 72.5576999172655
# ******************
# epoch:  152
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  66.54602187160349
# ******************
# acc_reward 66.54602187160349
# ******************
# epoch:  153
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  68.68525717095756
# ******************
# acc_reward 68.68525717095756
# ******************
# epoch:  154
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  59.08642419846039
# ******************
# acc_reward 59.08642419846039
# ******************
# epoch:  155
# task:  0
# task:  0 delay:  0 step:  83 acc_reward:  31.14740775371458
# ******************
# acc_reward 31.14740775371458
# ******************
# epoch:  156
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  119.4723106873745
# ******************
# acc_reward 119.4723106873745
# ******************
# epoch:  157
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  113.01371213878382
# ******************
# acc_reward 113.01371213878382
# ******************
# epoch:  158
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  100.16200477248947
# ******************
# acc_reward 100.16200477248947
# ******************
# epoch:  159
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  63.39005043112218
# ******************
# acc_reward 63.39005043112218
# ******************
# epoch:  160
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  107.50734803228211
# ******************
# acc_reward 107.50734803228211
# ******************
# epoch:  161
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  96.16193826752175
# ******************
# acc_reward 96.16193826752175
# ******************
# epoch:  162
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  57.91040758309714
# ******************
# acc_reward 57.91040758309714
# ******************
# epoch:  163
# task:  0
# task:  0 delay:  1 step:  178 acc_reward:  50.84549002891453
# ******************
# acc_reward 50.84549002891453
# ******************
# epoch:  164
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  76.05781043108718
# ******************
# acc_reward 76.05781043108718
# ******************
# epoch:  165
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  76.99486385773403
# ******************
# acc_reward 76.99486385773403
# ******************
# epoch:  166
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  131.21556510696553
# ******************
# acc_reward 131.21556510696553
# ******************
# epoch:  167
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  164.3633565202954
# ******************
# acc_reward 164.3633565202954
# ******************
# epoch:  168
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  172.59517489552263
# ******************
# acc_reward 172.59517489552263
# ******************
# epoch:  169
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  73.31690189053238
# ******************
# acc_reward 73.31690189053238
# ******************
# epoch:  170
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  71.23909180869961
# ******************
# acc_reward 71.23909180869961
# ******************
# epoch:  171
# task:  0
# task:  0 delay:  3 step:  114 acc_reward:  22.866192887374538
# ******************
# acc_reward 22.866192887374538
# ******************
# epoch:  172
# task:  0
# task:  0 delay:  1 step:  148 acc_reward:  23.557768069101858
# ******************
# acc_reward 23.557768069101858
# ******************
# epoch:  173
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  41.06507013485047
# ******************
# acc_reward 41.06507013485047
# ******************
# epoch:  174
# task:  0
# task:  0 delay:  3 step:  65 acc_reward:  8.04014914743792
# ******************
# acc_reward 8.04014914743792
# ******************
# epoch:  175
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  38.106925748883675
# ******************
# acc_reward 38.106925748883675
# ******************
# epoch:  176
# task:  0
# task:  0 delay:  1 step:  127 acc_reward:  49.05389495462245
# ******************
# acc_reward 49.05389495462245
# ******************
# epoch:  177
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  67.3053938250576
# ******************
# acc_reward 67.3053938250576
# ******************
# epoch:  178
# task:  0
# task:  0 delay:  1 step:  200 acc_reward:  82.72822957230494
# ******************
# acc_reward 82.72822957230494
# ******************
# epoch:  179
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  116.05120085554226
# ******************
# acc_reward 116.05120085554226
# ******************
# epoch:  180
# task:  0
# task:  0 delay:  0 step:  200 acc_reward:  95.33538467892234
# ******************
# acc_reward 95.33538467892234
# ******************
# epoch:  181
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  70.228837609537
# ******************
# acc_reward 70.228837609537
# ******************
# epoch:  182
# task:  0
# task:  0 delay:  2 step:  200 acc_reward:  88.38590418986598
# ******************
# acc_reward 88.38590418986598
# ******************
# epoch:  183
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  54.1245460465087
# ******************
# acc_reward 54.1245460465087
# ******************
# epoch:  184
# task:  0
# task:  0 delay:  3 step:  200 acc_reward:  63.25715308644361
# ******************
# acc_reward 63.25715308644361
# ******************
# epoch:  185
# task:  0
# task:  0 delay:  0 step:  103 acc_reward:  36.781321831902105
# ******************
# acc_reward 36.781321831902105
# ******************
# epoch:  186
# task:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-cc538557706e> in <module>
#      28                 action = np.array([0.0])
#      29                 if i > 1:
# ---> 30                     action = np.array([mpc_controller.act(task=env_copy, model=model, state=np.concatenate((obs, act_buf)))])
#      31                 act_buf = np.concatenate((act_buf, action))
#      32                 obs_next, reward, done, state_next = env.step([act_buf[-1-delay_step]])
#
# ~/robustNP/mpc/mpc_cp.py in act(self, task, model, state, ground_truth)
#      62         self.ground_truth = ground_truth
#      63
# ---> 64         soln, var = self.optimizer.obtain_solution(self.prev_sol, self.init_var)
#      65         if self.type == "CEM":
#      66             self.prev_sol = np.concatenate([np.copy(soln)[self.action_dim:], np.zeros(self.action_dim)])
#
# ~/robustNP/mpc/optimizers/random.py in obtain_solution(self, *args, **kwargs)
#      62         solutions = self.sampler.sample(self.size).cpu().numpy()[:,:,0]
#      63         #solutions = np.random.uniform(self.lb, self.ub, [self.popsize, self.sol_dim])
# ---> 64         costs = self.cost_function(solutions)
#      65         return solutions[np.argmin(costs)], None
#
# ~/robustNP/mpc/mpc_cp.py in cartpole_cost_function(self, actions)
#     107
#     108
# --> 109                 state_predict = self.model.predict(state, action)
#     110                 state_next = state_predict + state
#     111                 state_next[:,5:] = state_predict[:,5:]
#
# ~/robustNP/baselines/NP_epi.py in predict(self, s, a)
#     181
#     182         # NOTICE: forward the NP
# --> 183         mu, sigma, log_p, kl, loss = self.model(context_x, context_y, target_x, None, print_latent=True)
#     184
#     185         # TODO: not sure about the output dim of mu and sigma
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/robustNP/baselines/ANP/NPModel.py in forward(self, context_x, context_y, target_x, target_y, print_latent)
#      86         # NOTICE: obtain r using deterministic path
#      87         if self.use_deter_path:
# ---> 88             R = self._deter_encoder(context_x, context_y, target_x)
#      89             # R (B, target_size, latent_dim)
#      90         else:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/robustNP/baselines/ANP/module.py in forward(self, context_x, context_y, target_x)
#     257         # In my paper, all x are first passed by lstm
#     258         #
# --> 259         h = self._cross_attention(context_x, hidden_r_i, target_x)
#     260         # context_x     (b, seq_len, input_x_dim)           # Key
#     261         # hidden_r_i    (b, seq_len, latent_dim)            # Value
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/robustNP/baselines/ANP/module.py in forward(self, k, v, q)
#     427             k = self.batch_mlp_k(k)
#     428             q = self.batch_mlp_q(q)
# --> 429         rep = self._attention_func(k, v, q)
#     430         return rep
#     431
#
# ~/robustNP/baselines/ANP/module.py in _multihead_attention(self, k, v, q)
#     458             k_ = self._W_k[i](k)
#     459             v_ = self._W_v[i](v)
# --> 460             q_ = self._W_q[i](q)
#     461             out = self._dot_attention(k_, v_, q_)
#     462             outs.append(out)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in __getitem__(self, idx)
#     133
#     134     def __getitem__(self, idx):
# --> 135         if isinstance(idx, slice):
#     136             return self.__class__(list(self._modules.values())[idx])
#     137         else:
#
# KeyboardInterrupt:
